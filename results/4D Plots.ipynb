# %%
import numpy
from pylab import *
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
data=numpy.loadtxt("4cD_results.txt")
dim=data[:,0]
size=data[:,1]
sz=data[:,1]
q=data[:,2]
temp=data[:,3]
mag=data[:,4]
emag=data[:,5]
c_inds=numpy.arange(6,26,2)
corr=data[:,c_inds]
ecorr=data[:,c_inds+1]

gpts=numpy.where(size != 100)
dim=dim[gpts]
size=size[gpts]
sz=sz[gpts]
q=q[gpts]
temp=temp[gpts]
mag=mag[gpts]
emag=emag[gpts]
corr=corr[gpts]
ecorr=ecorr[gpts]

qs=numpy.unique(q)
print(qs)
for i in range(0,len(qs)):
    figure(figsize=(8,6))
    sizes=numpy.unique(size)
    pts=numpy.where(q == qs[i])
    ising_temp=temp[pts]
    ising_mag=mag[pts]
    ising_corr=corr[pts]
    ising_size=size[pts]
    for j in range(0,len(sizes)):
        inds=where(ising_size==sizes[j])
        plot(ising_temp[inds],ising_mag[inds],label=str(sizes[j]))
    legend(loc="upper right",title="Size")
    xlim(0,5.0)
    ylim(0,1.2)
    savefig("q"+str(qs[i])+"_size_effect_4d.png")
# Out:
# [  2.   3.   4.   5.  10.]

# %%
clf()
figure(figsize=(12,6))
qs=numpy.unique(q)
pts=numpy.where(size == 32)
l_temp=temp[pts]
l_mag=mag[pts]
l_corr=corr[pts]
l_ecorr=ecorr[pts]
l_q=q[pts]
for i in range(0,len(qs)):
    inds=where(l_q==qs[i])
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    plot(l_temp[inds],l_mag[inds],label=str(qs[i]),color=color)
legend(loc="upper right",title="Q")
xlim(0,4.0)
ylim(0,1.2)
show()

figure(figsize=(12,6))
lcorr1=l_corr[:,0]
lcorr2=l_corr[:,2]
lcorr3=l_corr[:,4]
for i in range(0,len(qs)):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])
    plot(l_temp[inds],lcorr1[inds],label="r1, q="+str(qs[i]),color=color)
    plot(l_temp[inds],lcorr2[inds],'--',label="r2, q="+str(qs[i]),color=color)
    plot(l_temp[inds],lcorr3[inds],':',label="r3, q="+str(qs[i]),color=color)
legend(loc="center right",title="r, Q")
xlim(0,4)
ylim(0,1.2)
show()

# %%
def func(r,a):
    return -a*r-2.0*log(r)

rlim=8
figure(figsize=(10,6))
x=numpy.arange(1,rlim,1)
fakezero=1e-4
Tcr=qs*0.0
for i in range(0,len(qs)):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])

    xtemp=l_temp[inds]
    xcorr=l_corr[inds]
    xmag=l_mag[inds]
    
    xi=xtemp*0.0
    for j in range(0,len(xcorr)):
        icorr=xcorr[j][1:rlim]
        pts=numpy.where(icorr < fakezero)
        icorr[pts]=fakezero
        popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
        xi[j]=1/popt[0]
   
    Tcr[i]=xtemp[numpy.argmax(xi)]
    plot(xtemp,xi,label="Corr(r), Tc="+str(Tcr[i]),color=color)

xlabel("Temperature")
ylabel("Relaxation Length")
ylim(0,3)
legend(loc="upper right")

def func2(r,a,b,c):
    return a*exp(-r/c)/(pow(r,b))

figure(figsize=(10,6))
x=numpy.arange(1,rlim,1)
fakezero=1e-10
for i in range(0,len(qs)):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])

    xtemp=l_temp[inds]
    xcorr=l_corr[inds]
    excorr=l_ecorr[inds]
    xmag=l_mag[inds]
    
    xi=xtemp*0.0
    gpts=where(xtemp==Tcr[i])
    icorr=xcorr[gpts[0][0]][1:rlim]
    eicorr=excorr[gpts[0][0]][1:rlim]
    pts=numpy.where(icorr < fakezero)
    icorr[pts]=fakezero
    plot(x,icorr,':',color=color)
    popt,pcov =curve_fit(func2,x,icorr,sigma=eicorr,p0=(1.0,0.25,10.0))
    print(popt)
    #plot(x,icorr,':',color=color)
    plot(x,func2(x,popt[0],popt[1],popt[2]),label="Corr(r), Tc="+str(Tcr[i])+", Nu="+"{0:5.3f}".format(popt[1]),color=color)
    
xlabel("Temperature")
ylabel("Relaxation Length")
legend(loc="upper right")
# Out:
# [  1.86416629e-01   2.14514927e+00  -2.98126943e+07]
# [  1.72205522e-01   2.17373868e+00   5.61151951e+02]
# [  1.05180557e-01   3.27204137e+00   1.63252886e+07]
# [  7.40094339e-02   3.56027949e+00   2.37774590e+06]
# [ 0.00509032 -0.68671077  3.98516482]

# %%
def func(r,a):
    return -a*r-2.0*log(r)

def func2(r,a,b,c):
    return a*exp(-r/c)/(pow(r,b))

sizes=numpy.unique(size)
for qi in range(0,len(qs)):
    figure(figsize=(8,6))
    pts=numpy.where(q == qs[qi])
    l_temp=temp[pts]
    l_mag=mag[pts]
    l_corr=corr[pts]
    l_ecorr=ecorr[pts]
    lsize=sz[pts]

    figure(figsize=(10,6))
    x=numpy.arange(1,rlim,1)
    fakezero=1e-4
    Tcr=sizes*0.0
    for i in range(0,len(sizes)):
        if(i == 0):
            color="magenta"
        if(i == 1):
            color="blue"
        if(i == 2):
            color="green"
        if(i == 3):
            color="red"
        if(i == 4):
            color="orange"
        if(i == 5):
            color="black"
        inds=where(lsize==sizes[i])

        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        for j in range(0,len(xcorr)):
            icorr=xcorr[j][1:rlim]
            pts=numpy.where(icorr < fakezero)
            icorr[pts]=fakezero
            popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
            xi[j]=1/popt[0]
   
        Tcr[i]=xtemp[numpy.argmax(xi)]
        plot(xtemp,xi,label=str(sizes[i])+", Tc="+str(Tcr[i]),color=color)

    xlabel("Temperature")
    ylabel("Relaxation Length")
    ylim(0,5)
    legend(loc="upper right")

# %%
figure(figsize=(10,6))
for qi in range(0,len(qs)):
    pts=numpy.where(q == qs[qi])
    l_temp=temp[pts]
    l_mag=mag[pts]
    l_corr=corr[pts]
    l_ecorr=ecorr[pts]
    lsize=sz[pts]

    x=numpy.arange(1,len(l_corr[0]),1)
    fakezero=1e-4
    Tcr=sizes*0.0
    for i in range(0,len(sizes)):
        inds=where(lsize==sizes[i])
        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        for j in range(0,len(xcorr)):
            icorr=xcorr[j][1:len(xcorr[j])]
            pts=numpy.where(icorr < fakezero)
            icorr[pts]=fakezero
            popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
            xi[j]=1/popt[0]
        Tcr[i]=xtemp[numpy.argmax(xi)]

    x=numpy.arange(1,6,1)
    fakezero=1e-10
    nu=sizes*0
    for i in range(1,len(sizes)):

        inds=where(lsize==sizes[i])

        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        excorr=l_ecorr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        gpts=where(xtemp==Tcr[i])
        icorr=xcorr[gpts[0][0]][1:6]
        eicorr=excorr[gpts[0][0]][1:6]
        pts=numpy.where(icorr < fakezero)
        icorr[pts]=fakezero
        #plot(x,icorr,':',color=color)
        popt,pcov =curve_fit(func2,x,icorr,sigma=eicorr,p0=(1.0,0.25,10.0))
        #print(popt)
        nu[i]=popt[1]
        #plot(x,icorr,':',color=color)
        #plot(x,func2(x,popt[0],popt[1],popt[2]),label="Corr(r), Tc="+str(Tcr[i])+", Nu="+"{0:5.3f}".format(popt[1]),color=color)
    
    if(qi == 0):
        color="black"
    if(qi == 1):
        color="blue"
    if(qi == 2):
        color="green"
    if(qi == 3):
        color="red"
    if(qi == 4):
        color="orange"
    if(qi == 5):
        color="black"
    plot(sizes[1:],nu[1:],label="q="+str(qs[qi])+", best Nu="+"{0:5.3f}".format(nu[-1]),color=color)
    print(nu)
    xlabel("Lattice Size")
    ylabel("R Power Law Parameter 'Nu'")
    xscale('log')
    legend(loc="lower right")
# Out:
# [ 0.          2.04176089  2.12131112]
# [ 0.          2.93184555  2.23538551]
# [ 0.          2.67438883  3.03203923]
# [ 0.          3.42201389  3.40431149]
# [ 0.          3.46178658  2.31975736]

# %%
figure(figsize=(10,6))
for qi in range(0,len(qs)-1):
    pts=numpy.where(q == qs[qi])
    l_temp=temp[pts]
    l_mag=mag[pts]
    l_corr=corr[pts]
    l_ecorr=ecorr[pts]
    lsize=sz[pts]

    x=numpy.arange(1,len(l_corr[0]),1)
    fakezero=1e-4
    Tcr=sizes*0.0
    for i in range(0,len(sizes)):
        inds=where(lsize==sizes[i])
        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        for j in range(0,len(xcorr)):
            icorr=xcorr[j][1:len(xcorr[j])]
            pts=numpy.where(icorr < fakezero)
            icorr[pts]=fakezero
            popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
            xi[j]=1/popt[0]
        Tcr[i]=xtemp[numpy.argmax(xi)]
    
    if(qi == 0):
        color="black"
    if(qi == 1):
        color="blue"
    if(qi == 2):
        color="green"
    if(qi == 3):
        color="red"
    if(qi == 4):
        color="orange"
    if(qi == 5):
        color="black"
    theoretical=1/log(1+sqrt(qs[qi]))
    plot(sizes,Tcr,label="q="+str(qs[qi])+", best Tc="+"{0:5.3f}".format(Tcr[-1]),color=color)
    plot([10,100],[theoretical,theoretical],':',color=color,label="q=2, theory, Tc="+"{0:5.3f}".format(theoretical))
    xlabel("Lattice Size")
    ylabel("Critical Temperature")
    xscale('log')
    legend(loc="lower right",ncol=2)
