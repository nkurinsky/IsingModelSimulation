# %%
import numpy
from pylab import *
import scipy
from scipy.optimize import curve_fit
# %matplotlib inline

# %%
data=numpy.loadtxt("2cD_results.txt")
dim=data[:,0]
size=data[:,1]
sz=data[:,1]
q=data[:,2]
temp=data[:,3]
mag=data[:,4]
emag=data[:,5]
c_inds=numpy.arange(6,26,2)
corr=data[:,c_inds]
ecorr=data[:,c_inds+1]

qs=numpy.unique(q)
for i in range(0,len(qs)):
    figure(figsize=(8,6))
    sizes=numpy.unique(size)
    pts=numpy.where(q == qs[i])
    ising_temp=temp[pts]
    ising_mag=mag[pts]
    ising_corr=corr[pts]
    ising_size=size[pts]
    for j in range(0,len(sizes)):
        inds=where(ising_size==sizes[j])
        plot(ising_temp[inds],ising_mag[inds],label=str(sizes[j]))
    legend(loc="upper right",title="Size")
    xlim(0,2.5)
    ylim(0,1.2)
    title("Spin Q="+str(int(qs[i])))
    xlabel("Potts Temperature")
    ylabel("Magnetization")
    savefig("q"+str(int(qs[i]))+"_size_effect.pdf")

# %%
clf()
figure(figsize=(8,6))
qs=numpy.unique(q)
pts=numpy.where(size == 1000)
l_temp=temp[pts]
l_mag=mag[pts]
l_corr=corr[pts]
l_ecorr=ecorr[pts]
l_q=q[pts]
for i in range(0,len(qs)-1):
    inds=where(l_q==qs[i])
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    plot(l_temp[inds],l_mag[inds],label=str(qs[i]),color=color)
legend(loc="upper right",title="Q")
xlim(0.5,1.5)
ylim(0,1.2)
title("2D Magnetization")
xlabel("Potts Temperature")
ylabel("Magnetization")
savefig("2D_allspin.png")

figure(figsize=(8,6))
lcorr1=l_corr[:,0]
lcorr2=l_corr[:,2]
lcorr3=l_corr[:,4]
for i in range(0,len(qs)-1):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])
    plot(l_temp[inds],lcorr1[inds],label="r1, q="+str(qs[i]),color=color)
    plot(l_temp[inds],lcorr2[inds],'--',label="r2, q="+str(qs[i]),color=color)
    plot(l_temp[inds],lcorr3[inds],':',label="r3, q="+str(qs[i]),color=color)
legend(loc="center left",title="r, Q")
xlim(0,2)
ylim(0,1.2)
title("2D Correlation")
xlabel("Potts Temperature")
ylabel("Correlation")
savefig("2D_allspin_corr.png")

# %%
def func(r,a):
    return -a*r-1/4*log(r)

figure(figsize=(10,6))
x=numpy.arange(1,len(l_corr[0]),1)
fakezero=1e-4
Tcr=qs*0.0
for i in range(0,len(qs)-1):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])

    xtemp=l_temp[inds]
    xcorr=l_corr[inds]
    xmag=l_mag[inds]
    
    xi=xtemp*0.0
    for j in range(0,len(xcorr)):
        icorr=xcorr[j][1:len(xcorr[j])]
        pts=numpy.where(icorr < fakezero)
        icorr[pts]=fakezero
        popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
        xi[j]=1/popt[0]
   
    Tcr[i]=xtemp[numpy.argmax(xi)]
    plot(xtemp,xi,label="Corr(r), Tc="+str(Tcr[i]),color=color)

xlabel("Temperature")
ylabel("Relaxation Length")
ylim(0,7)
legend(loc="upper right")

def func2(r,a,b,c):
    return a*exp(-r/c)/(pow(r,b))

figure(figsize=(10,6))
x=numpy.arange(1,10,1)
fakezero=1e-10
for i in range(0,len(qs)-1):
    if(i == 0):
        color="black"
    if(i == 1):
        color="blue"
    if(i == 2):
        color="green"
    if(i == 3):
        color="red"
    if(i == 4):
        color="orange"
    inds=where(l_q==qs[i])

    xtemp=l_temp[inds]
    xcorr=l_corr[inds]
    excorr=l_ecorr[inds]
    xmag=l_mag[inds]
    
    xi=xtemp*0.0
    gpts=where(xtemp==Tcr[i])
    icorr=xcorr[gpts[0][0]][1:10]
    eicorr=excorr[gpts[0][0]][1:10]
    pts=numpy.where(icorr < fakezero)
    icorr[pts]=fakezero
    plot(x,icorr,':',color=color)
    popt,pcov =curve_fit(func2,x,icorr,sigma=eicorr,p0=(1.0,0.25,10.0))
    print(popt)
    print(pcov)
    #plot(x,icorr,':',color=color)
    plot(x,func2(x,popt[0],popt[1],popt[2]),label="Corr(r), Tc="+str(Tcr[i])+", Nu="+"{0:5.3f}".format(popt[1]),color=color)
    
xlabel("Temperature")
ylabel("Relaxation Length")
legend(loc="upper right")
# Out:
# [  0.69478143   0.26965924  66.48189445]
# [[  1.10167136e-06  -7.41990885e-07  -2.24886266e-03]
#  [ -7.41990885e-07   1.40680391e-05   1.85683067e-02]
#  [ -2.24886266e-03   1.85683067e-02   2.67789940e+01]]
# [  0.66693326   0.3142821   31.43918289]
# [[  3.46501113e-06  -6.23862648e-06  -2.83242265e-03]
#  [ -6.23862648e-06   5.23867386e-05   1.67288200e-02]
#  [ -2.83242265e-03   1.67288200e-02   5.76216559e+00]]
# [  0.63087186   0.3645627   11.23826882]
# [[  1.18745719e-05   5.26270037e-06  -3.02562506e-04]
#  [  5.26270037e-06   1.38288691e-04   5.20520575e-03]
#  [ -3.02562506e-04   5.20520575e-03   2.22395869e-01]]
# [ 0.60809183  0.40040015  8.36206366]
# [[  5.41219384e-06  -5.08162268e-06  -2.22754099e-04]
#  [ -5.08162268e-06   1.17981803e-04   2.36963276e-03]
#  [ -2.22754099e-04   2.36963276e-03   5.24783854e-02]]
# [ 0.54948745  0.54587749  2.2520058 ]
# [[  5.10952030e-05  -1.64574592e-04  -4.56025887e-04]
#  [ -1.64574592e-04   7.24235648e-04   1.73474932e-03]
#  [ -4.56025887e-04   1.73474932e-03   4.53023651e-03]]

# %%
def func(r,a):
    return -a*r-1/4*log(r)

def func2(r,a,b,c):
    return a*exp(-r/c)/(pow(r,b))

sizes=numpy.unique(size)
for qi in range(0,len(qs)):
    if(qs[qi] != 4):
        figure(figsize=(8,6))
        pts=numpy.where(q == qs[qi])
        l_temp=temp[pts]
        l_mag=mag[pts]
        l_corr=corr[pts]
        l_ecorr=ecorr[pts]
        lsize=sz[pts]

        figure(figsize=(10,6))
        x=numpy.arange(1,len(l_corr[0]),1)
        fakezero=1e-4
        Tcr=sizes*0.0
        for i in range(0,len(sizes)):
            if(i == 0):
                color="magenta"
            if(i == 1):
                color="blue"
            if(i == 2):
                color="green"
            if(i == 3):
                color="red"
            if(i == 4):
                color="orange"
            if(i == 5):
                color="black"
            inds=where(lsize==sizes[i])

            xtemp=l_temp[inds]
            xcorr=l_corr[inds]
            xmag=l_mag[inds]
    
            xi=xtemp*0.0
            for j in range(0,len(xcorr)):
                icorr=xcorr[j][1:len(xcorr[j])]
                pts=numpy.where(icorr < fakezero)
                icorr[pts]=fakezero
                popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
                xi[j]=1/popt[0]
   
            Tcr[i]=xtemp[numpy.argmax(xi)]
            plot(xtemp,xi,label=str(sizes[i])+", Tc="+str(Tcr[i]),color=color)

        xlabel("Temperature")
        ylabel("Relaxation Length")
        ylim(0,7)
        legend(loc="upper right")

# %%
figure(figsize=(10,6))
for qi in range(0,len(qs)-2):
    if(qs[qi] == 4):
        continue
    pts=numpy.where(q == qs[qi])
    l_temp=temp[pts]
    l_mag=mag[pts]
    l_corr=corr[pts]
    l_ecorr=ecorr[pts]
    lsize=sz[pts]

    x=numpy.arange(1,10,1)
    fakezero=1e-4
    Tcr=sizes*0.0
    for i in range(0,len(sizes)):
        inds=where(lsize==sizes[i])
        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        for j in range(0,len(xcorr)):
            icorr=xcorr[j][1:10]
            pts=numpy.where(icorr < fakezero)
            icorr[pts]=fakezero
            popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
            xi[j]=1/popt[0]
        Tcr[i]=xtemp[numpy.argmax(xi)]

    x=numpy.arange(1,10,1)
    fakezero=1e-10
    nu=sizes*0
    for i in range(1,len(sizes)):

        inds=where(lsize==sizes[i])

        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        excorr=l_ecorr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        gpts=where(xtemp==Tcr[i])
        icorr=xcorr[gpts[0][0]][1:10]
        eicorr=excorr[gpts[0][0]][1:10]
        pts=numpy.where(icorr < fakezero)
        icorr[pts]=fakezero
        popt,pcov =curve_fit(func2,x,icorr,sigma=eicorr,p0=(1,0.25,100.0))
        nu[i]=popt[1]
    
    if(qi == 0):
        color="black"
        theor=0.25
        plot([24,1000],[theor,theor],':',color=color,label="q=2, theory, Nu=0.25")
    if(qi == 1):
        color="blue"
        theor=5.0/16.0
        plot([24,1000],[theor,theor],':',color=color,label="q=3, theory, Nu=0.313")
    if(qi == 2):
        color="green"
    if(qi == 3):
        color="red"
    if(qi == 4):
        color="orange"
    if(qi == 5):
        color="black"
    plot(sizes,nu,label="q="+str(qs[qi])+", best Nu="+"{0:5.3f}".format(nu[-1]),color=color)
    xlabel("Lattice Size")
    ylabel("R Power Law Parameter 'Nu'")
    xlim(24,1000)
    xscale('log')
    legend(loc="upper right")

# %%
figure(figsize=(10,6))
for qi in range(0,len(qs)-1):
    if(qs[qi] == 4):
        continue
    pts=numpy.where(q == qs[qi])
    l_temp=temp[pts]
    l_mag=mag[pts]
    l_corr=corr[pts]
    l_ecorr=ecorr[pts]
    lsize=sz[pts]

    x=numpy.arange(1,len(l_corr[0]),1)
    fakezero=1e-4
    Tcr=sizes*0.0
    for i in range(0,len(sizes)):
        inds=where(lsize==sizes[i])
        xtemp=l_temp[inds]
        xcorr=l_corr[inds]
        xmag=l_mag[inds]
    
        xi=xtemp*0.0
        for j in range(0,len(xcorr)):
            icorr=xcorr[j][1:len(xcorr[j])]
            pts=numpy.where(icorr < fakezero)
            icorr[pts]=fakezero
            popt,pcov=curve_fit(func,x,log(icorr),p0=(1e-5))
            xi[j]=1/popt[0]
        Tcr[i]=xtemp[numpy.argmax(xi)]
    
    if(qi == 0):
        color="black"
    if(qi == 1):
        color="blue"
    if(qi == 2):
        color="green"
    if(qi == 3):
        color="red"
    if(qi == 4):
        color="orange"
    if(qi == 5):
        color="black"
    theoretical=1/log(1+sqrt(qs[qi]))
    plot(sizes,Tcr,label="q="+str(qs[qi])+", best Tc="+"{0:5.3f}".format(Tcr[-1]),color=color)
    plot([10,1000],[theoretical,theoretical],':',color=color,label="q=2, theory, Tc="+"{0:5.3f}".format(theoretical))
    xlabel("Lattice Size")
    ylabel("Critical Temperature")
    ylim(0.4,1.3)
    xscale('log')
    legend(loc="lower right",ncol=2)
